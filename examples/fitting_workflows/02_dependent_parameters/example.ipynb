# %% [markdown]
# # Fitting with Dependent (Linked) Parameters
#
# This notebook shows how to link fit parameters to one another with expressions, so that physically related quantities are tied together instead of fit independently. Linking parameters encodes known physics directly into the model and reduces the number of free parameters, making fits faster and more robust.
#
# The example system shown here is an X-ray Photoelectron Spectroscopy (XPS) spin-orbit doublet (Au 4f). Two Gaussian–Lorentzian-product (`GLP`) peaks sit on an `Offset` + `Shirley` background. The two peaks are not independent: as a 4f spin-orbit doublet they share
# - a fixed intensity ratio (here 3:4),
# - a fixed energy splitting (here +3.67 eV),
# - the same line shape (width `F` and mixing `m`).
#
# So only the first peak's amplitude, position, and line shape are fit; all parameters of the second peak are derived from the first through expressions. See `models_energy.yaml` for the implementation.
#
# The workflow mirrors [`01_basic_fitting`](../01_basic_fitting/example.ipynb) but focuses on the linked parameters (and skips slice-by-slice fitting):
# 1. **Select the data**: load, inspect, and set the fit limits.
# 2. **Fit the baseline** (`base`): fit the ground-state doublet, then confirm the links held.
# 3. **Global 2D fit** (`2D`): add a time-dependence to the first peak's position; the second peak's position inherits it through its expression.
# 4. **Inspect the results.**

# %%
from pathlib import Path

import numpy as np
import trspecfit

# %% [markdown]
# ## 1. Load and Inspect Data
#
# ### 1.1 Load Data
#
# Load time- and energy-resolved XPS data from CSV files. Unlike the synthetic dataset in [`01_basic_fitting`](../01_basic_fitting/example.ipynb), this is real, measured data: Au 4f spectra acquired at beamline 9.3.1 of the Advanced Light Source, with a ±1 V sample-bias modulation at 0.25 Hz switched on at t = 0. There are no "truth" files; instead, the known physics of the Au 4f doublet and the applied modulation anchor the fit (see §4). The 2D `data` array is `[time, energy]`, i.e. rows are time, columns are energy.

# %%
# Create project (YAML model files are resolved relative to this path)
project = trspecfit.Project(path=Path.cwd())

# Directory containing data files
data_folder = 'data'

# Add file to project
file = trspecfit.File(
    parent_project=project,
    path=data_folder,
    data=np.loadtxt(project.path / data_folder / 'data.csv', delimiter=','),
    energy=np.loadtxt(project.path / data_folder / 'energy.csv'),
    time=np.loadtxt(project.path / data_folder / 'time.csv')
)

# %% [markdown]
# ### 1.2 Inspect Data
#
# Two overlapping `GLP` peaks (the spin-orbit doublet) sit on a Shirley background. After t = 0 the doublet position oscillates in time.

# %%
# Visualize full dataset
file.describe()

# %% [markdown]
# ### 1.3 Define Fitting Region
#
# Set energy and time limits for the fits. They appear as black, dotted lines in the plot.

# %%
# Set fitting limits (absolute values)
file.set_fit_limits(
    energy_limits=[91, 81],  # Energy range in eV (descending binding-energy axis)
    time_limits=[-0.3, 16.5]  # Time range
)

# %% [markdown]
# ## 2. Fit Baseline with Linked Parameters
#
# ### 2.1 Define Baseline Spectrum
#
# Extract the ground-state spectrum by averaging the pre-perturbation time slices.

# %%
# Define baseline using time indices
# Indices 0-3 are the four slices before t = 0; the modulation starts at t = 0,
# so the slice at index 4 (t ~ 0) must not bleed into the baseline.
file.define_baseline(
    time_start=0,
    time_stop=3,
    time_type='ind'  # Use indices (or 'abs' for absolute time values)
)

# %% [markdown]
# ### 2.2 The Baseline Model and Its Linked Parameters
#
# The model is defined in `models_energy.yaml`. The first peak (`GLP_01`) is fit normally. The second peak (`GLP_02`) is linked to the first through expressions instead of being given its own free parameters:
#
# ```yaml
# GLP:                       # GLP_01 -- fit freely
#   A:  [200, True, 0, 1000]
#   x0: [84.5, True, 82, 88]
#   F:  [1.0, True, 0.75, 2.5]
#   m:  [0.3, True, 0, 1]
# GLP:                       # GLP_02 -- derived from GLP_01
#   A:  ["3/4*GLP_01_A"]     # intensity ratio
#   x0: ["GLP_01_x0 + 3.67"] # energy splitting (eV)
#   F:  ["GLP_01_F"]         # shared width
#   m:  ["GLP_01_m"]         # shared mixing
# ```
#
# **How to reference a parameter:** use its full name `{component}_{NN}_{parameter}`, where `NN` is the two-digit, auto-assigned component number (e.g. `GLP_01_A`). There is no `$` prefix.
#
# **What you can write in an expression**
#
# | Pattern | Example | Notes |
# |---------|---------|-------|
# | Copy | `"GLP_01_F"` | tie a parameter to another |
# | Scale / ratio | `"3/4*GLP_01_A"` | fixed intensity ratio |
# | Offset | `"GLP_01_x0 + 3.67"` | fixed splitting |
# | Several parameters | `"GLP_01_A * GLP_01_x0 / 85"` | arithmetic `+ - * / ** %` |
# | Fan-out | many peaks → one base `GLP_01_A` | static scaling of a shared base |
# | Reference a dynamic base | `"GLP_01_x0 + 3.67"` where `GLP_01_x0` is time-dependent | the expression inherits the dynamics (see §3) |
#
# **What you cannot do**
# - Chain through a time- or profile-varying parameter (`C → B → A_dynamic`). Reference the varying base directly instead.
# - Self / circular references.
# - Add dynamics or a profile to an expression parameter — add them to the base parameter it references.
#
# See [`docs/design/supported_models.md`](../../../docs/design/supported_models.md) for the full contract.
#
# During the fit, the values of all fixed parameters (`vary=False`) and all expression parameters are derived automatically; only `GLP_01`'s free parameters and the background are optimized.

# %%
# Load baseline model
file.load_model(
    model_yaml='models_energy.yaml',
    model_info='base'
)

# Inspect model structure -- note the expr column for the GLP_02 parameters
file.describe_model(model_info='base', detail=0)
#file.model_active.visualize() # visualize model as a graph

# %%
# Fit baseline model to data
# stages=1: single optimization
# stages=2: two-stage (global + local)
file.fit_baseline(
    model_name='base',
    stages=2,
    try_ci=0  # Confidence intervals: see 12_uncertainty_mcmc
)

# %% [markdown]
# ### 2.3 Confirm the Linked Parameters
#
# `GLP_02` was never fit independently — its parameters are computed from `GLP_01` via the expressions above. Reading the results back confirms the intensity ratio is exactly 3/4 and the splitting exactly 3.67 eV, with peak 2 carrying no free parameters of its own.

# %%
# Read the linked parameters back from the baseline fit results
res = file.get_fit_results(fit_type='baseline').set_index('name')

A1, A2 = res.loc['GLP_01_A', 'value'], res.loc['GLP_02_A', 'value']
x1, x2 = res.loc['GLP_01_x0', 'value'], res.loc['GLP_02_x0', 'value']

print(f"GLP_02_A  = {A2:8.3f}   expr {res.loc['GLP_02_A', 'expr']!r:>16}   ->  A2 / A1   = {A2 / A1:.3f}")
print(f"GLP_02_x0 = {x2:8.3f}   expr {res.loc['GLP_02_x0', 'expr']!r:>16}   ->  x2 - x1   = {x2 - x1:.3f} eV")

# %% [markdown]
# ## 3. Global 2D Fitting with an Inherited Dynamic Link
#
# Now fit the whole dataset at once and let the first peak's position move in time. We attach a time law (`sine_wave` from `models_time.yaml`) to `GLP_01_x0`.
#
# The key point: `GLP_02_x0` is defined as `"GLP_01_x0 + 3.67"`. Because it references the now time-dependent `GLP_01_x0` directly, the second peak's position **inherits** the oscillation automatically — it tracks peak 1 at a fixed 3.67 eV offset, with no extra parameters. (This works precisely because the expression points at the dynamic base directly; chaining through another expression would not be allowed.)
#
# **Why global?**
# Fitting all time points together with a single time law constrains the dynamics across the whole dataset, giving far fewer free parameters and more robust results than fitting each slice independently.

# %%
# Load 2D model (same linked doublet; fixed parameters are pinned to the baseline result)
file.load_model(
    model_yaml='models_energy.yaml',
    model_info='2D'
)

file.describe_model(model_info='2D', detail=0)

# %%
# Attach a sine-wave time law to the first peak's position.
# GLP_02_x0 = "GLP_01_x0 + 3.67" will inherit this oscillation automatically.
file.add_time_dependence(
    target_model='2D',
    target_parameter='GLP_01_x0',
    dynamics_yaml='models_time.yaml',
    dynamics_model='sine_wave',
)

print("\n=== Model with Time Dependence ===")
file.describe_model(model_info='2D', detail=1)
#file.model_active.visualize() # visualize model as a graph

# %%
# Perform global 2D fit
file.fit_2d(
    model_name='2D',
    stages=2,
    try_ci=0  # Skip confidence interval estimation for a faster fit
)

# %% [markdown]
# ## 4. Inspect the Fit Results
#
# `file.get_fit_results(fit_type='2d')` returns a `pandas.DataFrame` with one row per parameter. The first peak's position now carries the sine-wave dynamics parameters (`GLP_01_x0_sinFun_01_*`), while `GLP_02_x0` keeps its expression in the `expr` column — confirming peak 2 follows peak 1 plus 3.67 eV across all time points, with no free parameters of its own.
#
# Since this is measured data the recovered fit parameters can be compared to the experimental parameters and the known literature values. The fitted modulation frequency (`f` ≈ 0.2502 Hz) recovers the applied 0.25 Hz bias modulation, the fitted 4f<sub>7/2</sub> position lands near the tabulated Au 4f<sub>7/2</sub> binding energy of 84.0 eV, and the 3.67 eV splitting and 3:4 intensity ratio enforced by the expressions are themselves the literature values for the Au 4f spin-orbit doublet. Note that the fitted oscillation amplitude (≈ 0.84 eV) is smaller than the ±1 V drive: the sample's response to the input bias is damped, while the frequency carries over unchanged.
#
# For more on accessing fit results and metadata, see [`10_model_comparison`](../10_model_comparison/example.ipynb).

# %%
file.get_fit_results(fit_type='2d')

# %% [markdown]
# ## Tips for Dependent Parameters
#
# **Writing expressions**
# - Reference a parameter by its full name `{component}_{NN}_{parameter}` (e.g. `GLP_01_A`); there is no `$` prefix.
# - Use arithmetic (`+ - * / ** %`); expressions are evaluated by the same safe evaluator lmfit uses.
# - Common patterns: spin-orbit splitting, vibrational progressions, shared backgrounds, fixed intensity ratios.
#
# **Allowed vs. not allowed**
# - Supported: link to other top-level parameters; static fan-out from a shared base; reference a time-dependent or profiled base directly (the expression inherits the variation).
# - Not supported: chain through a varying parameter (`C → B → A_dynamic`) — reference the base directly. No self / circular references. Don't attach dynamics or profiles to an expression parameter.
# - Source of truth: [`docs/design/supported_models.md`](../../../docs/design/supported_models.md).
#
# **Strategy**
# - Fewer free parameters → more robust, faster fits. Use links to encode known physics.
# - Fit the baseline first to establish good initial values for the shared / base parameters.
# - Add a time law to the base parameter and let the linked parameters inherit it.
#
# ## Next Steps
# - Datasets with multiple sub-cycles: [`03_multi_cycle_dynamics`](../03_multi_cycle_dynamics/example.ipynb)
# - Parameters that vary along an auxiliary axis: [`04_parameter_profiles`](../04_parameter_profiles/example.ipynb)
# - Uncertainty estimation (MCMC): [`12_uncertainty_mcmc`](../12_uncertainty_mcmc/example.ipynb)
# - Save, load, and export fits: [`11_save_load_export`](../11_save_load_export/example.ipynb)
