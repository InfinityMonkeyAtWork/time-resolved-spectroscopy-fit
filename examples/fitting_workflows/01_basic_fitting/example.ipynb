# %% [markdown]
# # Basic Fitting Workflow
#
# This notebook demonstrates the standard fitting workflow for time- and energy-resolved spectroscopy data.
#
# **Example System:**
# - Single Gaussian-Lorentzian Product (GLP) peak
# - Components: offset + linear background
# - Time dependence: exponential shift of peak position (with IRF convolution)
#
# **Workflow:**
# 1. Load and inspect data
# 2. Fit baseline (ground state) spectrum
# 3. Slice-by-Slice fitting to identify time-dependent parameters
# 4. Global 2D fitting with parametric time dependence

# %%
import os
import numpy as np
import trspecfit
from trspecfit.utils.lmfit import MC  # For uncertainty estimation

# %% [markdown]
# ## 1. Load Data
#
# Load simulated time- and energy-resolved spectroscopy data from CSV files.

# %%
# Create project
project = trspecfit.Project(path=os.getcwd())

# %%
# Load data from CSV files
data_folder = 'data'

file = trspecfit.File(
    parent_project=project,
    path=data_folder,
    data=np.loadtxt(project.path / data_folder / 'data.csv', delimiter=','),
    energy=np.loadtxt(project.path / data_folder / 'energy.csv'),
    time=np.loadtxt(project.path / data_folder / 'time.csv')
)

print(f"Data shape: {file.data.shape}")
print(f"Energy range: {file.energy.min():.1f} - {file.energy.max():.1f}")
print(f"Time range: {file.time.min():.1f} - {file.time.max():.1f}")

# %% [markdown]
# ## 2. Inspect Data
#
# Visualize the raw data to identify features and appropriate fitting regions.

# %%
# Visualize full dataset
file.describe()

# %% [markdown]
# ## 3. Define Fitting Region
#
# Set energy and time limits to focus on the region of interest.

# %%
# Set fitting limits (absolute values)
file.set_fit_limits(
    energy_limits=[5, 18],  # Energy range
    time_limits=[-10, 99]  # Time range
)

# %% [markdown]
# ## 4. Define Baseline Spectrum
#
# Extract the ground state/pre-trigger spectrum by averaging over early time points.

# %%
# Define baseline using time indices
file.define_baseline(
    time_start=0,
    time_stop=12,
    time_type='ind'  # Use indices (or 'abs' for absolute time values)
)

# %% [markdown]
# ## 5. Fit Baseline Spectrum
#
# Fit the ground state spectrum to establish initial parameters for time-dependent fits.

# %%
# Load baseline model
file.load_model(
    model_yaml='models_energy.yaml',
    model_info='base'
)

# Inspect model structure and parameters
file.describe_model(model_info="base", detail=0)
#file.model_active.visualize() # visualize model as a graph

# %%
# Fit baseline model to data
# stages=1: single optimization
# stages=2: two-stage (global + local)
file.fit_baseline(model_name='base', stages=2)

# %% [markdown]
# ## 6. (Optional) Slice-by-Slice Fitting
#
# Fit each time slice independently to get an idea of how parameters evolve over time.

# %%
# Load Slice-by-Slice model
file.load_model(
    model_yaml='models_energy.yaml',
    model_info='SbS'
)

file.describe_model('SbS', detail=0)

# %%
# Perform Slice-by-Slice fit
file.fit_slice_by_slice(
    model_name='SbS',
    stages=1,
    try_ci=0  # Set to 1 to calculate confidence intervals (slower)
)

# %% [markdown]
# ## 7. Global 2D Fitting
#
# Fit the entire 2D dataset simultaneously with time-dependent parameters.
#
# ### Key Advantage:
# Global fitting constrains parameters across all time points, reducing overfitting and providing more robust parameter estimates.

# %%
# Load 2D model
file.load_model(
    model_yaml='models_energy.yaml',
    model_info='2D'
)

file.describe_model(model_info='2D', detail=0)

# %%
# Add time dependence to parameter
file.add_time_dependence(
    target_model='2D',
    target_parameter='GLP_01_x0',
    dynamics_yaml='models_time.yaml',
    dynamics_model='MonoExpPosIRF',
)

print("\n=== Model with Time Dependence ===")
file.describe_model(model_info='2D', detail=1)
#file.model_active.visualize() # visualize model as a graph

# %%
# Configure uncertainty estimation (optional)
mc_settings = MC(
    use_mc=0,  # Set to 1 to use Monte Carlo uncertainty estimation
    steps=5000,
    nwalkers=20,
    thin=1
)

# Perform global 2D fit
file.fit_2d(
    model_name='2D',
    stages=2,
    try_ci=0,  # Set to 1 for confidence intervals
    mc_settings=mc_settings
)

# %% [markdown]
# ## 8. Inspect the Fit Results
#
# `file.get_fit_results(fit_type=...)` returns a `pandas.DataFrame` for programmatic access — one row per parameter for `baseline` / `spectrum` / `2d`, one row per time slice for `sbs`.

# %%
file.get_fit_results(fit_type="2d")

# %% [markdown]
# ## 9. Export Fits for External Tools
#
# `file.export_fit()` writes a **one-way** CSV + PNG tree intended for humans and tools like Origin / MATLAB / paper plots. For a 2D fit it drops `params.csv`, `metrics.csv`, `fit_2d.csv`, `observed_2d.csv`, `energy.csv`, `time.csv`, and `2D_data_fit_res.png` into a directory; baseline yields a slimmer 1D tree. There is no `load` counterpart — for round-tripping back into trspecfit, use `save_fit` (§10 below).
#
# **Auto-export default.** Each `fit_*` method already writes a similar CSV/PNG tree under `project.path_results` **on completion** — that's the `Project.auto_export = True` default. Set `project.auto_export = False` (or `auto_export: false` in `project.yaml`) to suppress the side effect; explicit `file.export_fit()` and `project.export_fits()` calls always write regardless of the flag. The opt-out is useful for parameter sweeps, ML training-data generation, and real-time fitting where the per-fit dumps are noise.

# %%
# Show the auto-export side effect, then disable it for the rest of the notebook.
print("auto_export default:", project.auto_export)
print("path_results:       ", project.path_results)

# Opt out of auto-export so the explicit export call below is the only thing
# that writes to disk from here on. Equivalent: set auto_export: false in
# project.yaml.
project.auto_export = False

# Explicit, re-runnable export — same CSVs/PNGs as the fit-completion writes,
# but on demand and with filter kwargs (model=..., fit_type=...) when needed.
file.export_fit("basic_fit_export", overwrite=True)

from pathlib import Path
for p in sorted(Path("basic_fit_export").rglob("*")):
    if p.is_file():
        print(f"  {p}")

# %% [markdown]
# ## 10. Save a Fit-Results Snapshot
#
# `file.save_fit()` writes a structured HDF5 archive of this file's fits. It is the **round-trippable** counterpart to `export_fit`: the saved slot keeps the full σ snapshot, params, observed/fit arrays, and metrics, and `trspecfit.FitResults.load(path)` reads it back without needing a live `Project`. Snapshot semantics — one slot per `(model, fit_type, selection)` for this file, latest write wins on save.
#
# For comparing two models on the same file, browsing a loaded archive, or shipping only the winning slot, see [`10_model_comparison`](../10_model_comparison/example.ipynb) and [`11_save_load_export`](../11_save_load_export/example.ipynb).

# %%
file.save_fit("basic_fit.fit.h5", overwrite=True)

loaded = trspecfit.FitResults.load("basic_fit.fit.h5")
print(loaded)

# %% [markdown]
# ## Tips for Basic Fitting
#
# **Fitting Strategy:**
# - Always fit baseline first to establish good initial values
# - Use Slice-by-Slice to identify which parameters are time-dependent
# - Apply time-dependence only to parameters that clearly evolve
# - Start with simple time-dependencies (exponential) before complex ones
#
# **Fit Levels:**
# - `stages=1`: Single optimization pass
# - `stages=2`: Two-stage fitting (global + local) for more robust results
#
# **Uncertainty Estimation:**
# - `try_ci=1`: Fast linear approximation of confidence intervals
# - `MC` with `use_mc=1`: More robust Monte Carlo estimation
#
# **Inspect / Export / Save:**
# - `file.get_fit_results(fit_type=...)` returns a DataFrame for programmatic use.
# - `file.export_fit()` writes CSV + PNG for Origin / MATLAB / paper plots — one-way, no `load`.
# - `file.save_fit()` writes a round-trippable HDF5 archive — pair with `trspecfit.FitResults.load(path)` to reopen later.
# - `project.auto_export = False` (or `auto_export: false` in `project.yaml`) suppresses the per-fit CSV/PNG dumps under `project.path_results`. Explicit `export_fit` / `save_fit` calls always write.
#
# **Next Steps:**
# - See `02_dependent_parameters` for fitting with parameter constraints
# - See `03_multi_cycle_dynamics` for fitting datasets with multiple sub-cycles
# - See `10_model_comparison` for comparing two models on the same data
# - See `11_save_load_export` for the full archive API: filtered ship-the-winners, browsing a loaded archive, σ-snapshot recalibration
